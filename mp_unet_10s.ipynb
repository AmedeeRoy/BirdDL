# %% [markdown]
# <a href="https://colab.research.google.com/github/AmedeeRoy/BirdDL/blob/main/mp_unet_10s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dive Prediction - Deep Network
#
# *Predicting Seabird Diving Behaviour from GPS data*
#
# This notebook trains a neural network to predict seabirds' dives.
#
# Networks' characteristics:
#
# * *Trajectory window* : 300s
# * *Output resolution*: 1s
# * *Representation of trajectories* : Matrix Distance
# * *Layers* : 1x1 convolutions

# %% [markdown]
# ## connect to drive

# %%
# mount google drive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/My\ Drive/
# Out:
# /content/drive/My Drive

# %% [markdown]
# ## load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

from utils.trip import *

# %%
data_train = pd.read_csv('./data/data_train.csv')
data_validation = pd.read_csv('./data/data_validation.csv')
data_test = pd.read_csv('./data/data_test.csv')

# %% [markdown]
# ## choose window

# %%
class Sample(object):
    def __init__(self, ratio):
        self.ratio = ratio

    def __call__(self, sample):
        traj, dive = sample

        # change resolution
        idx = [i%self.ratio == 0 for i in range(traj.shape[1])]
        traj_new = traj[:,idx]
        dive_new = [np.max(dive[i:i+self.ratio]) for i in range(len(dive)) if i%self.ratio==0]


        return (traj_new, dive_new)

# %%
# Hyperparameters
resolution = 10
window = 100 * resolution
variable = ('lon', 'lat')

train_set = TrajDataSet(data_train, window, variable)
d = DistMatrix()
s = Sample(resolution)

# %%
plt.figure(figsize=(16, 10))
idx = np.random.randint(0, len(train_set), 4)

k = -1
for i in idx:
    k += 1
    traj, dive = train_set[i]
    matrix_dist, dive = d(s(train_set[i]))
    

    plt.subplot(2,4, k+1)
    plt.imshow(matrix_dist)

    plt.subplot(2,4, k+5)
    dive = [dive[i] for i in range(len(dive)) for k in range(resolution) ]
    plt.plot(traj[0,:], traj[1,:])
    plt.scatter(traj[0, np.array(dive, dtype = 'bool')], traj[1,np.array(dive, dtype = 'bool')], c='orange')

# %% [markdown]
# # Neural Network

# %%
# hyperparameters
batch_size = 64

## reduce size dataset
train_set = TrajDataSet(data_train, window, variable, transform = transforms.Compose([Sample(resolution), DistMatrix(), ToTensor()]))
validation_set = TrajDataSet(data_validation, window, variable, transform = transforms.Compose([Sample(resolution), DistMatrix(), ToTensor()]))

train_loader = DataLoader(train_set, batch_size=batch_size, num_workers = 0, shuffle = True, drop_last=True)
validation_loader = DataLoader(validation_set, batch_size=batch_size, num_workers = 0, shuffle = True, drop_last=True)

# %%
class UNet(nn.Module):

    def __init__(self):
        super(UNet, self).__init__()

        self.threshold = nn.Sequential(
            nn.BatchNorm2d(1),
            nn.Conv2d(1, 8, kernel_size = 1, stride = 1, padding = 0, dilation = 1, bias = True),
            nn.ReLU()
        )

        self.cnn_input_1 = nn.Sequential(
            nn.BatchNorm1d(8),
            nn.Conv1d(8, 16, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(16, 16, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.pooling_1 = nn.Sequential(
            nn.MaxPool1d(kernel_size = 11, stride = 2, padding = 5, dilation = 1)
        )

        self.cnn_input_2 = nn.Sequential(
            nn.BatchNorm1d(16),
            nn.Conv1d(16, 32, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(32, 32, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.pooling_2 = nn.Sequential(
            nn.MaxPool1d(kernel_size = 11, stride = 2, padding = 5, dilation = 1)
        )

        self.cnn_input_3 = nn.Sequential(
            nn.BatchNorm1d(32),
            nn.Conv1d(32, 32, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(32, 32, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.upconv_2 = nn.Sequential(
             nn.ConvTranspose1d(32, 16, kernel_size = 6, stride = 2, padding = 2, dilation = 1)
         )

        self.cnn_output_2 = nn.Sequential(
            nn.BatchNorm1d(32+16),
            nn.Conv1d(32+16, 32, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(32, 16, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.upconv_1 = nn.Sequential(
             nn.ConvTranspose1d(16, 8, kernel_size = 6, stride = 2, padding = 2, dilation = 1)
         )
        
        self.cnn_output_1 = nn.Sequential(
            nn.BatchNorm1d(16+8),
            nn.Conv1d(16+8, 16, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(16, 8, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv1d(8, 1, kernel_size = 11, stride = 1, padding = 5, dilation = 1)
        )

    def forward(self, x):
        out = self.threshold(x)
        out = torch.sum(out, 2)
        out = self.cnn_input_1(out)
        out_1 = out.clone()
        out = self.pooling_1(out)
        out = self.cnn_input_2(out)
        out_2 = out.clone()
        out = self.pooling_2(out)
        out = self.cnn_input_3(out)

        out = self.upconv_2(out)
        out = torch.cat((out, out_2), 1)
        out = self.cnn_output_2(out)

        out = self.upconv_1(out)
        out = torch.cat((out, out_1), 1)
        out = self.cnn_output_1(out)

        return out

def get_score(out, y):
    out, y = out.cpu(), y.cpu()
    out = 1*(out>0)
    true_positive = np.mean(out[y == True].numpy()) 
    true_negative = 1-np.mean(out[y == False].numpy())
    
    return (round(true_positive*100) , round(true_negative*100))

# %%
# get sample
x, y = next(iter(train_loader)) 
weight = torch.FloatTensor([20])

# Forward model
model = UNet()

out = model(x)

# Loss and score
learning_rate = 0.01
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.BCEWithLogitsLoss(pos_weight = weight)
criterion(out, y)
get_score(out, y)
# Out:
# (4.0, 93.0)

# %%
## get Loss weight
torch.sum(y==y)/torch.sum(y)
# Out:
# tensor(21.2625)

# %% [markdown]
# ## Training

# %%
# switch to GPU
model = UNet()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
weight = weight.to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight = weight)

# %%
# Train the model
nb_epoch = 3
weight = torch.FloatTensor([20])
learning_rate = 0.01

list_loss_train = []
list_score_train = []

list_loss_validation = []
list_score_validation = []


for epoch in range(nb_epoch):
    learning_rate /= 10
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    i = 0
    for batch, (x, y) in enumerate(train_loader):
        i+=1
        # send to GPU
        x, y = x.to(device), y.to(device)

        # Run the forward pass
        out = model(x)
        loss = criterion(out, y)

        # Backprop and perform optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        score = get_score(out,y)
        list_loss_train.append(loss.item())
        list_score_train.append(score)

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Batch Loss: {}, Batch True Positive : {}, Batch True Negative : {} %'
                    .format(epoch+1, nb_epoch, i + 1, len(train_loader), loss.item(), score[0], score[1]))

    ### - Validation every epoch
    model.eval()
    with torch.no_grad():
        j = 0
        for batch, (x, y) in enumerate(validation_loader):
            j+= 1
            # send to GPU
            x, y = x.to(device), y.to(device)

            # Run the forward pass
            out = model(x)
            loss = criterion(out, y)
            score = get_score(out,y)
            list_loss_validation.append(loss.item())
            list_score_validation.append(score)

    global_loss = np.mean(list_loss_validation)
    global_trueP = np.mean([tp for (tp, tn) in list_score_validation])
    global_trueN = np.mean([tn for (tp, tn) in list_score_validation])

    print('Validation -------------------------------------------------------------------------------------')
    print('Epoch [{}/{}], Validation Loss: {}, Validation True Positive : {}, Validation True Negative : {} %'
            .format(epoch+1, nb_epoch, global_loss, global_trueP, global_trueN))
    print('------------------------------------------------------------------------------------------------')
    model.train()
# Out:
# Epoch [1/3], Step [100/1886], Batch Loss: 0.7244998216629028, Batch True Positive : 89.0, Batch True Negative : 70.0 %
# Epoch [1/3], Step [200/1886], Batch Loss: 0.6896857619285583, Batch True Positive : 95.0, Batch True Negative : 69.0 %
# Epoch [1/3], Step [300/1886], Batch Loss: 0.7218872308731079, Batch True Positive : 95.0, Batch True Negative : 70.0 %
# Epoch [1/3], Step [400/1886], Batch Loss: 0.6312358975410461, Batch True Positive : 97.0, Batch True Negative : 72.0 %
# Epoch [1/3], Step [500/1886], Batch Loss: 0.7757766842842102, Batch True Positive : 96.0, Batch True Negative : 69.0 %
# Epoch [1/3], Step [600/1886], Batch Loss: 0.5880278944969177, Batch True Positive : 94.0, Batch True Negative : 76.0 %
# Epoch [1/3], Step [700/1886], Batch Loss: 0.951327919960022, Batch True Positive : 83.0, Batch True Negative : 71.0 %
# Epoch [1/3], Step [800/1886], Batch Loss: 0.7761102914810181, Batch True Positive : 95.0, Batch True Negative : 70.0 %
# Epoch [1/3], Step [900/1886], Batch Loss: 0.5775173306465149, Batch True Positive : 99.0, Batch True Negative : 75.0 %
# Epoch [1/3], Step [1000/1886], Batch Loss: 0.588102400302887, Batch True Positive : 96.0, Batch True Negative : 78.0 %
# Epoch [1/3], Step [1100/1886], Batch Loss: 0.49041062593460083, Batch True Positive : 96.0, Batch True Negative : 81.0 %
# Epoch [1/3], Step [1200/1886], Batch Loss: 0.4903029501438141, Batch True Positive : 94.0, Batch True Negative : 82.0 %
# Epoch [1/3], Step [1300/1886], Batch Loss: 0.5524484515190125, Batch True Positive : 96.0, Batch True Negative : 80.0 %
# Epoch [1/3], Step [1400/1886], Batch Loss: 0.44117027521133423, Batch True Positive : 96.0, Batch True Negative : 84.0 %
# Epoch [1/3], Step [1500/1886], Batch Loss: 0.5716871023178101, Batch True Positive : 96.0, Batch True Negative : 78.0 %
# Epoch [1/3], Step [1600/1886], Batch Loss: 0.5178624987602234, Batch True Positive : 96.0, Batch True Negative : 81.0 %
# Epoch [1/3], Step [1700/1886], Batch Loss: 0.47523173689842224, Batch True Positive : 98.0, Batch True Negative : 82.0 %
# Epoch [1/3], Step [1800/1886], Batch Loss: 0.37042349576950073, Batch True Positive : 98.0, Batch True Negative : 85.0 %
# Validation -------------------------------------------------------------------------------------
# Epoch [1/3], Validation Loss: 2.706465360583091, Validation True Positive : 56.74285714285714, Validation True Negative : 79.08979591836734 %
# ------------------------------------------------------------------------------------------------
# Epoch [2/3], Step [100/1886], Batch Loss: 0.49596962332725525, Batch True Positive : 97.0, Batch True Negative : 83.0 %
# Epoch [2/3], Step [200/1886], Batch Loss: 0.4272889196872711, Batch True Positive : 92.0, Batch True Negative : 87.0 %
# Epoch [2/3], Step [300/1886], Batch Loss: 0.350864440202713, Batch True Positive : 98.0, Batch True Negative : 88.0 %
# Epoch [2/3], Step [400/1886], Batch Loss: 0.3249610662460327, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [2/3], Step [500/1886], Batch Loss: 0.2882409393787384, Batch True Positive : 99.0, Batch True Negative : 90.0 %
# Epoch [2/3], Step [600/1886], Batch Loss: 0.4084538519382477, Batch True Positive : 98.0, Batch True Negative : 85.0 %
# Epoch [2/3], Step [700/1886], Batch Loss: 0.4364110231399536, Batch True Positive : 95.0, Batch True Negative : 87.0 %
# Epoch [2/3], Step [800/1886], Batch Loss: 0.32814353704452515, Batch True Positive : 98.0, Batch True Negative : 88.0 %
# Epoch [2/3], Step [900/1886], Batch Loss: 0.4086238145828247, Batch True Positive : 98.0, Batch True Negative : 85.0 %
# Epoch [2/3], Step [1000/1886], Batch Loss: 0.3226768970489502, Batch True Positive : 100.0, Batch True Negative : 88.0 %
# Epoch [2/3], Step [1100/1886], Batch Loss: 0.38182273507118225, Batch True Positive : 94.0, Batch True Negative : 88.0 %
# Epoch [2/3], Step [1200/1886], Batch Loss: 0.34790340065956116, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [2/3], Step [1300/1886], Batch Loss: 0.2901197671890259, Batch True Positive : 99.0, Batch True Negative : 90.0 %
# Epoch [2/3], Step [1400/1886], Batch Loss: 0.42699718475341797, Batch True Positive : 98.0, Batch True Negative : 85.0 %
# Epoch [2/3], Step [1500/1886], Batch Loss: 0.3216181993484497, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [2/3], Step [1600/1886], Batch Loss: 0.2792596220970154, Batch True Positive : 99.0, Batch True Negative : 90.0 %
# Epoch [2/3], Step [1700/1886], Batch Loss: 0.5916504263877869, Batch True Positive : 96.0, Batch True Negative : 77.0 %
# Epoch [2/3], Step [1800/1886], Batch Loss: 0.3908054232597351, Batch True Positive : 91.0, Batch True Negative : 90.0 %
# Validation -------------------------------------------------------------------------------------
# Epoch [2/3], Validation Loss: 3.5103560498782564, Validation True Positive : 49.90102040816326, Validation True Negative : 81.62857142857143 %
# ------------------------------------------------------------------------------------------------
# Epoch [3/3], Step [100/1886], Batch Loss: 0.484648734331131, Batch True Positive : 96.0, Batch True Negative : 84.0 %
# Epoch [3/3], Step [200/1886], Batch Loss: 0.5537592172622681, Batch True Positive : 84.0, Batch True Negative : 87.0 %
# Epoch [3/3], Step [300/1886], Batch Loss: 0.46074944734573364, Batch True Positive : 96.0, Batch True Negative : 85.0 %
# Epoch [3/3], Step [400/1886], Batch Loss: 0.3104711174964905, Batch True Positive : 99.0, Batch True Negative : 89.0 %
# Epoch [3/3], Step [500/1886], Batch Loss: 0.376809686422348, Batch True Positive : 96.0, Batch True Negative : 89.0 %
# Epoch [3/3], Step [600/1886], Batch Loss: 0.29463353753089905, Batch True Positive : 99.0, Batch True Negative : 90.0 %
# Epoch [3/3], Step [700/1886], Batch Loss: 0.3148328363895416, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [3/3], Step [800/1886], Batch Loss: 0.30445054173469543, Batch True Positive : 96.0, Batch True Negative : 90.0 %
# Epoch [3/3], Step [900/1886], Batch Loss: 0.33247363567352295, Batch True Positive : 99.0, Batch True Negative : 88.0 %
# Epoch [3/3], Step [1000/1886], Batch Loss: 0.32892680168151855, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [3/3], Step [1100/1886], Batch Loss: 0.3805769383907318, Batch True Positive : 98.0, Batch True Negative : 88.0 %
# Epoch [3/3], Step [1200/1886], Batch Loss: 0.3339911699295044, Batch True Positive : 98.0, Batch True Negative : 88.0 %
# Epoch [3/3], Step [1300/1886], Batch Loss: 0.3020940124988556, Batch True Positive : 98.0, Batch True Negative : 90.0 %
# Epoch [3/3], Step [1400/1886], Batch Loss: 0.43309324979782104, Batch True Positive : 95.0, Batch True Negative : 88.0 %
# Epoch [3/3], Step [1500/1886], Batch Loss: 0.31972217559814453, Batch True Positive : 98.0, Batch True Negative : 89.0 %
# Epoch [3/3], Step [1600/1886], Batch Loss: 0.33282291889190674, Batch True Positive : 99.0, Batch True Negative : 88.0 %
# Epoch [3/3], Step [1700/1886], Batch Loss: 0.3757135272026062, Batch True Positive : 93.0, Batch True Negative : 90.0 %
# Epoch [3/3], Step [1800/1886], Batch Loss: 0.3122474253177643, Batch True Positive : 100.0, Batch True Negative : 88.0 %
# Validation -------------------------------------------------------------------------------------
# Epoch [3/3], Validation Loss: 3.716960499562374, Validation True Positive : 48.11632653061225, Validation True Negative : 82.32721088435375 %
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Testing

# %%
dive_real = []
dive_estim = []

for i in data_test.trip.unique():
    # create dataset for a trajectory
    t = data_test[data_test.trip == i].copy()    
    test_set = TrajDataSet(t, window, variable, transform = transforms.Compose([Rescale(rescale), DistMatrix(), ToTensor()]))
    test_set_part = [test_set[i] for i in range(len(test_set)) if i%rescale == 0]
    
    # Test the model
    estim = np.zeros(int((len(t))/rescale))
    nb = np.zeros(int((len(t))/rescale))
    
    list_out = []
    model.eval()
    k = 0
    with torch.no_grad():
        for (x, y) in test_set_part:
            # send to GPU
            x, y = x.to(device), y.to(device)

            # Run the forward pass
            out = model(x.unsqueeze(0))
            
            estim[k:k + round(window/rescale)] += out.cpu().squeeze().numpy()
            nb[k:k + round(window/rescale)] += 1
            k+=1

    
    # remove extra lines
    t = t.drop(t.tail(len(t)%rescale ).index)
    real = np.array([np.max(t.dive[i:i+rescale]) for i in range(len(t)) if i%rescale == 0])
    
    # add to list by trajectory
    dive_real.append(real)
    dive_estim.append(estim/nb)
    
    print(i)
# Out:
# P1108_46_SV_T2
# P1111_41_SV_T4
# P1112_10_SV_T2
# P1112_15_SV_T3
# P1112_20_SV_T4
# P1112_31_SV_T5
# P1113_28_SV_T1

# %%
threshold = 0
dive_plot = np.array([1*(estim[i]>threshold)  for i in range(len(estim)) for k in range(rescale) ])

# %%
plt.figure(figsize= (12, 5))
plt.subplot(1, 2, 1)
plt.plot(np.array(t.lon), np.array(t.lat))
plt.scatter(t.lon[t.dive == 1], t.lat[t.dive == 1], c = 'orange')

plt.subplot(1, 2, 2)
plt.plot(np.array(t.lon), np.array(t.lat))
plt.scatter(t.lon[dive_plot == 1], t.lat[dive_plot == 1], c = 'red')

# %% [markdown]
# ## score

# %%
# globally
all_real = 1* (np.hstack(dive_real)> 0)
all_estim = 1* (np.hstack(dive_estim) > 0)

true_positive = np.mean(all_estim[all_real == 1])
true_negative = 1-np.mean(all_estim[all_real == 0])

true_positive, true_negative
# Out:
# (0.7978723404255319, 0.8599148130619971)

# %%
# for each trip
fig, ax = plt.subplots()
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

for i in range(len(dive_real)):
    
    real = 1*(dive_real[i]>0)
    estim = 1*(dive_estim[i]>0)
    
    true_positive = np.mean(estim[real == 1])
    true_negative = 1-np.mean(estim[real == 0])

    ax.scatter(1-true_negative, true_positive, c = 'orange')
    
    print((true_positive, true_negative))
# Out:
# (0.42857142857142855, 0.878099173553719)
# (0.5714285714285714, 0.9233716475095786)
# (0.8333333333333334, 0.9105431309904153)
# (0.875, 0.7591036414565826)
# (0.9090909090909091, 0.8353413654618473)
# (1.0, 0.8235294117647058)
# (0.8461538461538461, 0.8853046594982079)

# %% [markdown]
# # ROC curve
#
# Change the decision threshold

# %%
# globally
TP = []
FP = []

all_real = 1* (np.hstack(dive_real)> 0)    
for tt in np.arange(-10, 10, 0.1):
    all_estim = 1* (np.hstack(dive_estim) > tt)
    true_positive = np.mean(all_estim[all_real == 1])
    true_negative = 1-np.mean(all_estim[all_real == 0])
    TP.append(true_positive)
    FP.append(1-true_negative)

# %%
plt.plot(np.array(FP), np.array(TP))

# %%
data = {'model': 'deep_network_matrix',
        'FP':  FP,
        'TP': TP
        }

df = pd.DataFrame (data, columns = ['model','FP','TP'])

df.to_csv('./roc_deep_network_matrix.csv', index = False)
# df.to_csv('./roc/roc_deep_network_matrix.csv', index = False)
