# %% [markdown]
# # Dive Prediction - Matrix Distance Simple Network
#
# *Predicting Seabird Diving Behaviour from GPS data*
#
# This notebook trains a neural network to predict seabirds' dives.
#
# Networks' characteristics:
#
# * *Trajectory window* : 100s
# * *Output resolution*: 10s
# * *Representation of trajectories* : Matrix Distance
# * *Layers* : 1x1 convolutions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

from utils.trip import *

# %%
data_train = pd.read_csv('./data/data_train.csv')
data_test = pd.read_csv('./data/data_test.csv')

# %% [markdown]
# ## choose window

# %%
# Hyperparameters
window = 600
rescale = 10
variable = ('lon', 'lat')

train_set = TrajDataSet(data_train, window, variable)
d = DistMatrix()
r = Rescale(rescale)

# %%
plt.figure(figsize=(16, 10))
idx = np.random.randint(0, len(train_set), 4)

k = -1
for i in idx:
    k += 1
    traj, dive = train_set[i]
    matrix_dist, dive = r(d(train_set[i]))
    

    plt.subplot(2,4, k+1)
    plt.imshow(matrix_dist)

    plt.subplot(2,4, k+5)
    dive = [dive[i] for i in range(len(dive)) for k in range(rescale) ]
    plt.plot(traj[0,:], traj[1,:])
    plt.scatter(traj[0, np.array(dive, dtype = 'bool')], traj[1,np.array(dive, dtype = 'bool')], c='orange')

# %% [markdown]
# # Neural Network

# %%
# hyperparameters
batch_size = 8
learning_rate = 0.01

train_set = TrajDataSet(data_train, window, variable, transform = transforms.Compose([Rescale(rescale), DistMatrix(), ToTensor()]))
train_loader = DataLoader(train_set, batch_size=batch_size, num_workers = 0, shuffle = True, drop_last=False)

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        
        self.im_cnn_1 = nn.Sequential(
            nn.Conv2d(1, 4, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv2d(4, 4, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.im_pooling_1 = nn.Sequential(
            nn.MaxPool2d(kernel_size = 50, stride = 2, padding = 24, dilation = 1)
        )

        self.im_cnn_2 = nn.Sequential(
            nn.Conv2d(4, 8, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv2d(8, 8, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.im_pooling_2 = nn.Sequential(
            nn.MaxPool2d(kernel_size = 15, stride = 2, padding = 7, dilation = 1)
        )

        self.im_cnn_3 = nn.Sequential(
            nn.Conv2d(8, 4, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU(),
            nn.Conv2d(4, 2, kernel_size = 11, stride = 1, padding = 5, dilation = 1),
            nn.ReLU()
        )

        self.im_pooling_3 = nn.Sequential(
            nn.MaxPool2d(kernel_size = 11, stride = 2, padding = 5, dilation = 4)
        )
       
        self.dt_cnn_1 = nn.Sequential(
            nn.Conv1d(2, 1, kernel_size = 11, stride = 1, padding = 5, dilation = 1)
        )
                
    def forward(self, x):
        # CNN
        out = self.im_cnn_1(x)
        out = self.im_pooling_1(out)
        out = self.im_cnn_2(out)
        out = self.im_pooling_2(out)
        out = self.im_cnn_3(out)
        out = self.im_pooling_3(out)

        # 
        out = torch.sum(out, 2)
        out = self.dt_cnn_1(out)

        return out

# %%
# get sample
x, y = next(iter(train_loader)) 

# Forward model
model = ConvNet()
out = model(x)

# Loss and score
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.BCEWithLogitsLoss(pos_weight = torch.FloatTensor([15]))
criterion(out, y)
get_score(out, y)
# Out:
# (0.0, 98.0)

# %% [markdown]
# ## Training

# %%
# # switch to GPU
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model.to(device)

# %%
# Train the model
list_loss = []
list_score = []
i = 0

for epoch in range(1):
    for batch, (x, y) in enumerate(train_loader):
        i+=1
    #     # send to GPU
    #     x, y = x.to(device), y.to(device)

        # Run the forward pass
        out = model(x)
        loss = criterion(out, y)

        # Backprop and perform optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i + 1) % 10 == 0:

            score = get_score(out,y)
            list_loss.append(loss.item())
            list_score.append(score)

            print('Epoch {}, Step {}, Loss: {}, True Positive : {}, True Negative : {} %'
                    .format(epoch+1, i + 1, loss.item(), score[0], score[1]))
# Out:
# Epoch 1, Step 10, Loss: 1.416369915008545, True Positive : 100.0, True Negative : 0.0 %
# Epoch 1, Step 20, Loss: 1.1434705257415771, True Positive : 100.0, True Negative : 0.0 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-51334b293381> in <module>
#      11
#      12         # Run the forward pass
# ---> 13         out = model(x)
#      14         loss = criterion(out, y)
#      15
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-24-5387847f1a43> in forward(self, x)
#      43         # CNN
#      44         out = self.im_cnn_1(x)
# ---> 45         out = self.im_pooling_1(out)
#      46         out = self.im_cnn_2(out)
#      47         out = self.im_pooling_2(out)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/pooling.py in forward(self, input)
#     157         return F.max_pool2d(input, self.kernel_size, self.stride,
#     158                             self.padding, self.dilation, self.ceil_mode,
# --> 159                             self.return_indices)
#     160
#     161
#
# ~/anaconda3/lib/python3.7/site-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     245             return if_true(*args, **kwargs)
#     246         else:
# --> 247             return if_false(*args, **kwargs)
#     248
#     249     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     574         stride = torch.jit.annotate(List[int], [])
#     575     return torch.max_pool2d(
# --> 576         input, kernel_size, stride, padding, dilation, ceil_mode)
#     577
#     578 max_pool2d = boolean_dispatch(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Testing

# %%
dive_real = []
dive_estim = []

for i in data_test.trip.unique():
    # create dataset for a trajectory
    t = data_test[data_test.trip == i].copy()    
    test_set = TrajDataSet(t, window, variable, transform = transforms.Compose([Rescale(rescale), DistMatrix(), ToTensor()]))
    test_set_part = [test_set[i] for i in range(len(test_set)) if i%rescale == 0]
    
    # Test the model
    estim = np.zeros(int((len(t))/rescale))
    nb = np.zeros(int((len(t))/rescale))
    
    list_out = []
    model.eval()
    k = 0
    with torch.no_grad():
        for (x, y) in test_set_part:
            # Run the forward pass
            out = model(x.unsqueeze(0))
            
            estim[k:k + round(window/rescale)] += out.squeeze().numpy()
            nb[k:k + round(window/rescale)] += 1
            k+=1

    
    # remove extra lines
    t = t.drop(t.tail(len(t)%rescale ).index)
    real = np.array([np.max(t.dive[i:i+rescale]) for i in range(len(t)) if i%rescale == 0])
    
    # add to list by trajectory
    dive_real.append(real)
    dive_estim.append(estim/nb)
    
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-0d28323a2eb8> in <module>
#       6     t = data_test[data_test.trip == i].copy()
#       7     test_set = TrajDataSet(t, window, variable, transform = transforms.Compose([Rescale(rescale), DistMatrix(), ToTensor()]))
# ----> 8     test_set_part = [test_set[i] for i in range(len(test_set)) if i%rescale == 0]
#       9
#      10     # Test the model
#
# <ipython-input-29-0d28323a2eb8> in <listcomp>(.0)
#       6     t = data_test[data_test.trip == i].copy()
#       7     test_set = TrajDataSet(t, window, variable, transform = transforms.Compose([Rescale(rescale), DistMatrix(), ToTensor()]))
# ----> 8     test_set_part = [test_set[i] for i in range(len(test_set)) if i%rescale == 0]
#       9
#      10     # Test the model
#
# ~/MEGA/SCRIPT/BirdDL/utils/trip.py in __getitem__(self, idx)
#     204
#     205         if self.transform:
# --> 206             sample = self.transform(sample)
#     207
#     208         return sample
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# ~/MEGA/SCRIPT/BirdDL/utils/trip.py in __call__(self, sample)
#     229     def __call__(self, sample):
#     230         traj, dive = sample
# --> 231         lon = np.vstack([traj[0] for i in range(traj.shape[1])])
#     232         lat = np.vstack([traj[1]  for i in range(traj.shape[1])])
#     233         dd = dist_ortho(lon, lat, lon.T, lat.T)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py in vstack(tup)
#     277         # raise warning if necessary
#     278         _arrays_for_stack_dispatcher(tup, stacklevel=2)
# --> 279     arrs = atleast_2d(*tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
#
# <__array_function__ internals> in atleast_2d(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/shape_base.py in atleast_2d(*arys)
#     124             result = ary.reshape(1, 1)
#     125         elif ary.ndim == 1:
# --> 126             result = ary[newaxis, :]
#     127         else:
#     128             result = ary
#
# KeyboardInterrupt:

# %%
threshold = 0
dive_plot = np.array([1*(estim[i]>threshold)  for i in range(len(estim)) for k in range(rescale) ])

# %%
plt.figure(figsize= (12, 5))
plt.subplot(1, 2, 1)
plt.plot(np.array(t.lon), np.array(t.lat))
plt.scatter(t.lon[t.dive == 1], t.lat[t.dive == 1], c = 'orange')

plt.subplot(1, 2, 2)
plt.plot(np.array(t.lon), np.array(t.lat))
plt.scatter(t.lon[dive_plot == 1], t.lat[dive_plot == 1], c = 'red')

# %% [markdown]
# ## score

# %%
# globally
all_real = 1* (np.hstack(dive_real)> 0)
all_estim = 1* (np.hstack(dive_estim) > 0)

true_positive = np.mean(all_estim[all_real == 1])
true_negative = 1-np.mean(all_estim[all_real == 0])

true_positive, true_negative
# Out:
# (0.7023411371237458, 0.7596491228070176)

# %%
# for each trip
fig, ax = plt.subplots()
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

for i in range(len(dive_real)):
    
    real = 1*(dive_real[i]>0)
    estim = 1*(dive_estim[i]>0)
    
    true_positive = np.mean(estim[real == 1])
    true_negative = 1-np.mean(estim[real == 0])

    ax.scatter(1-true_negative, true_positive, c = 'orange')
    
    print((true_positive, true_negative))
# Out:
# (0.9285714285714286, 0.8202479338842975)
# (0.42857142857142855, 0.89272030651341)
# (0.6875, 0.9249394673123487)
# (0.5, 0.8690095846645367)
# (0.7948717948717948, 0.6118012422360248)
# (0.78125, 0.5378151260504201)
# (0.7692307692307693, 0.752212389380531)
# (0.7272727272727273, 0.7429718875502008)
# (0.3684210526315789, 0.9195979899497487)
# (0.2857142857142857, 0.9583333333333334)
# (1.0, 0.19801980198019797)
# (0.5555555555555556, 0.7447698744769875)
# (0.0, 0.8760330578512396)
# (0.8181818181818182, 0.6294117647058823)
# (0.6875, 0.6621212121212121)
# (0.7692307692307693, 0.8422939068100359)
# (0.7083333333333334, 0.744270205066345)
# (0.8095238095238095, 0.6232558139534884)
# (0.7272727272727273, 0.8566243194192378)

# %% [markdown]
# # ROC curve
#
# Change the decision threshold

# %%
# globally
TP = []
FP = []

all_real = 1* (np.hstack(dive_real)> 0)    
for tt in np.arange(-5, 5, 0.1):
    all_estim = 1* (np.hstack(dive_estim) > tt)
    true_positive = np.mean(all_estim[all_real == 1])
    true_negative = 1-np.mean(all_estim[all_real == 0])
    TP.append(true_positive)
    FP.append(1-true_negative)

# %%
plt.plot(np.array(FP), np.array(TP))

# %%
data = {'model': 'deep_network_matrix',
        'FP':  FP,
        'TP': TP
        }

df = pd.DataFrame (data, columns = ['model','FP','TP'])

df.to_csv('./roc/roc_deep_network_matrix.csv', index = False)
